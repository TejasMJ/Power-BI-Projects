# %%
import pandas as pd

# %%
marketing_campaign_df = pd.read_csv('KAG_conversion_data.csv')

# %%
marketing_campaign_df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
print('Number of Rows in the dataset - ',marketing_campaign_df.shape[0])
print('Number of Columns in the dataset - ',marketing_campaign_df.shape[1])
# Out:
# Number of Rows in the dataset -  1143
# Number of Columns in the dataset -  11

# %%
print(marketing_campaign_df.dtypes)
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
missing_values = marketing_campaign_df.isnull().sum()
missing_values_percentage = missing_values / len(marketing_campaign_df)

missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})

missing_data
# Out:
#                      Missing Values  Percentage (%)
# ad_id                             0             0.0
# xyz_campaign_id                   0             0.0
# fb_campaign_id                    0             0.0
# age                               0             0.0
# gender                            0             0.0
# interest                          0             0.0
# Impressions                       0             0.0
# Clicks                            0             0.0
# Spent                             0             0.0
# Total_Conversion                  0             0.0
# Approved_Conversion               0             0.0

# %%
print(marketing_campaign_df.duplicated().sum())
# Out:
# 0

# %%
marketing_campaign_df = marketing_campaign_df.rename(columns={'xyz_campaign_id':'campaign_id'})

# %%
marketing_campaign_df
# Out:
#         ad_id  campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746          916          103916  30-34      M        15
# 1      708749          916          103917  30-34      M        16
# 2      708771          916          103920  30-34      M        20
# 3      708815          916          103928  30-34      M        28
# 4      708818          916          103928  30-34      M        28
# ...       ...          ...             ...    ...    ...       ...
# 1138  1314410         1178          179977  45-49      F       109
# 1139  1314411         1178          179978  45-49      F       110
# 1140  1314412         1178          179979  45-49      F       111
# 1141  1314414         1178          179981  45-49      F       113
# 1142  1314415         1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 0            7350       1    1.430000                 2                    1
# ...

# %%
from sqlalchemy import create_engine

server = 'DESKTOP-5V2R0U0\ADMIN'
database = 'marketing_campaign'

conn_str = f'mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes'

engine = create_engine(conn_str)
marketing_campaign_df.to_sql('Marketing_Campaign_Performance', engine, if_exists='replace', index=False)
# Out:
# 3
