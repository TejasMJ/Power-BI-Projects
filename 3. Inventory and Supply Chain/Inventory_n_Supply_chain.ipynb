# %%
import pandas as pd

# %%
inventory_df = pd.read_csv('retail_store_inventory.csv')

# %%
inventory_df
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001    Groceries  North              231
# 1      2022-01-01     S001      P0002         Toys  South              204
# 2      2022-01-01     S001      P0003         Toys   West              102
# 3      2022-01-01     S001      P0004         Toys  North              469
# 4      2022-01-01     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  2024-01-01     S005      P0016    Furniture   East               96
# 73096  2024-01-01     S005      P0017         Toys  North              313
# 73097  2024-01-01     S005      P0018     Clothing   West              278
# 73098  2024-01-01     S005      P0019         Toys   East              374
# 73099  2024-01-01     S005      P0020    Groceries   East              117
#
# ...

# %%
inventory_df.dtypes
# Out:
# Date                   object
# Store ID               object
# Product ID             object
# Category               object
# Region                 object
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Demand Forecast       float64
# Price                 float64
# Discount                int64
# Weather Condition      object
# Holiday/Promotion       int64
# Competitor Pricing    float64
# Seasonality            object
# dtype: object

# %%
print('Number of Rows in the dataset - ', inventory_df.shape[0])
print('Number of Columns in the dataset - ', inventory_df.shape[1])
# Out:
# Number of Rows in the dataset -  73100
# Number of Columns in the dataset -  15

# %%
missing_values = inventory_df.isnull().sum()
missing_percentage = (missing_values / len(missing_values)) % 100

missing_data = pd.DataFrame({'Missing Values' : missing_values, 'Percentage (%)': missing_percentage})
missing_data
# Out:
#                     Missing Values  Percentage (%)
# Date                             0             0.0
# Store ID                         0             0.0
# Product ID                       0             0.0
# Category                         0             0.0
# Region                           0             0.0
# Inventory Level                  0             0.0
# Units Sold                       0             0.0
# Units Ordered                    0             0.0
# Demand Forecast                  0             0.0
# Price                            0             0.0
# Discount                         0             0.0
# Weather Condition                0             0.0
# Holiday/Promotion                0             0.0
# Competitor Pricing               0             0.0
# Seasonality                      0             0.0

# %%
inventory_df[]
# Out:
# 2

# %%
from sqlalchemy import create_engine

server = 'DESKTOP-5V2R0U0\ADMIN'
database = 'inventory_supplychain'

conn_str = f'mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes'

engine = create_engine(conn_str)
inventory_df.to_sql('Inventory', engine, if_exists='replace', index='False')
